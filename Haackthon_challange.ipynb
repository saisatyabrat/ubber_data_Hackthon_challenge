# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
data=pd.read_csv(r"C:\Users\situ\Downloads\uber_rides_data.xlsx - sample_train.csv")

# %%
data
# Out:
#          ride_id  fare_amount          pickup_datetime  pickup_longitude  \
# 0       24238194          7.5  2015-05-07 19:52:06 UTC        -73.999817
# 1       27835199          7.7  2009-07-17 20:04:56 UTC        -73.994355
# 2       44984355         12.9  2009-08-24 21:45:00 UTC        -74.005043
# 3       25894730          5.3  2009-06-26 08:22:21 UTC        -73.976124
# 4       17610152         16.0  2014-08-28 17:47:00 UTC        -73.925023
# ...          ...          ...                      ...               ...
# 199995  42598914          3.0  2012-10-28 10:49:00 UTC        -73.987042
# 199996  16382965          7.5  2014-03-14 01:09:00 UTC        -73.984722
# 199997  27804658         30.9  2009-06-29 00:42:00 UTC        -73.986017
# 199998  20259894         14.5  2015-05-20 14:56:25 UTC        -73.997124
# 199999  11951496         14.1  2010-05-15 04:08:00 UTC        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# ...

# %%
data.shape
# Out:
# (200000, 8)

# %%
data.columns
# Out:
# Index(['ride_id', 'fare_amount', 'pickup_datetime', 'pickup_longitude',
#        'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude',
#        'passenger_count'],
#       dtype='object')

# %%
data['dropoff_longitude'].isnull().sum()
# Out:
# 1

# %%
data['pickup_datetime']=pd.to_datetime(data['pickup_datetime'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ride_id            200000 non-null  int64
#  1   fare_amount        200000 non-null  float64
#  2   pickup_datetime    200000 non-null  datetime64[ns, UTC]
#  3   pickup_longitude   200000 non-null  float64
#  4   pickup_latitude    200000 non-null  float64
#  5   dropoff_longitude  199999 non-null  float64
#  6   dropoff_latitude   199999 non-null  float64
#  7   passenger_count    200000 non-null  int64
# dtypes: datetime64[ns, UTC](1), float64(5), int64(2)
# memory usage: 12.2 MB

# %%
data.isnull().sum()
# Out:
# ride_id              0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data['Year'] = data['pickup_datetime'].dt.year
data['Month'] = data['pickup_datetime'].dt.month
data['Day'] = data['pickup_datetime'].dt.day
data['Day of Week'] = data['pickup_datetime'].dt.dayofweek

# %%
data
# Out:
#          ride_id  fare_amount           pickup_datetime  pickup_longitude  \
# 0       24238194          7.5 2015-05-07 19:52:06+00:00        -73.999817
# 1       27835199          7.7 2009-07-17 20:04:56+00:00        -73.994355
# 2       44984355         12.9 2009-08-24 21:45:00+00:00        -74.005043
# 3       25894730          5.3 2009-06-26 08:22:21+00:00        -73.976124
# 4       17610152         16.0 2014-08-28 17:47:00+00:00        -73.925023
# ...          ...          ...                       ...               ...
# 199995  42598914          3.0 2012-10-28 10:49:00+00:00        -73.987042
# 199996  16382965          7.5 2014-03-14 01:09:00+00:00        -73.984722
# 199997  27804658         30.9 2009-06-29 00:42:00+00:00        -73.986017
# 199998  20259894         14.5 2015-05-20 14:56:25+00:00        -73.997124
# 199999  11951496         14.1 2010-05-15 04:08:00+00:00        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199999 entries, 0 to 199999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ride_id            199999 non-null  int64
#  1   fare_amount        199999 non-null  float64
#  2   pickup_datetime    199999 non-null  datetime64[ns, UTC]
#  3   pickup_longitude   199999 non-null  float64
#  4   pickup_latitude    199999 non-null  float64
#  5   dropoff_longitude  199999 non-null  float64
#  6   dropoff_latitude   199999 non-null  float64
#  7   passenger_count    199999 non-null  int64
#  8   Year               199999 non-null  int64
#  9   Month              199999 non-null  int64
#  10  Day                199999 non-null  int64
#  11  Day of Week        199999 non-null  int64
# dtypes: datetime64[ns, UTC](1), float64(5), int64(6)
# memory usage: 19.8 MB

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['fare_amount'].max()
# Out:
# 499.0

# %%
data.describe().T
# Out:
#                       count          mean           std          min  \
# ride_id            199999.0  2.771248e+07  1.601386e+07     1.000000
# fare_amount        199999.0  1.135989e+01  9.901760e+00   -52.000000
# pickup_longitude   199999.0 -7.252763e+01  1.143782e+01 -1340.648410
# pickup_latitude    199999.0  3.993588e+01  7.720558e+00   -74.015515
# dropoff_longitude  199999.0 -7.252529e+01  1.311741e+01 -3356.666300
# dropoff_latitude   199999.0  3.992389e+01  6.794829e+00  -881.985513
# passenger_count    199999.0  1.684543e+00  1.385995e+00     0.000000
# Year               199999.0  2.011742e+03  1.856400e+00  2009.000000
# Month              199999.0  6.281791e+00  3.438933e+00     1.000000
# Day                199999.0  1.570474e+01  8.687377e+00     1.000000
# Day of Week        199999.0  3.048435e+00  1.946946e+00     0.000000
#
#                             25%           50%           75%           max
# ...

# %%
from math import radians, sin, cos, sqrt, atan2

# Function to calculate distance using haversine formula
def calculate_distance(lat1, lon1, lat2, lon2):
    # Convert decimal degrees to radians
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    
    # Radius of the Earth in kilometers
    R = 6371
    
    # Haversine formula
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = sin(dlat / 2) ** 2 + cos(lat1) * cos(lat2) * sin(dlon / 2) ** 2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = R * c
    
    return distance

# %%
data['Distance'] = data.apply(lambda row: calculate_distance(row['pickup_latitude'],
                                                         row['pickup_longitude'],
                                                         row['dropoff_latitude'],
                                                         row['dropoff_longitude']), axis=1)

# %%
data.head()
# Out:
#     ride_id  fare_amount           pickup_datetime  pickup_longitude  \
# 0  24238194          7.5 2015-05-07 19:52:06+00:00        -73.999817
# 1  27835199          7.7 2009-07-17 20:04:56+00:00        -73.994355
# 2  44984355         12.9 2009-08-24 21:45:00+00:00        -74.005043
# 3  25894730          5.3 2009-06-26 08:22:21+00:00        -73.976124
# 4  17610152         16.0 2014-08-28 17:47:00+00:00        -73.925023
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 0        40.738354         -73.999512         40.723217                1
# 1        40.728225         -73.994710         40.750325                1
# 2        40.740770         -73.962565         40.772647                1
# 3        40.790844         -73.965316         40.803349                3
# 4        40.744085         -73.973082         40.761247                5
#
#    Year  Month  Day  Day of Week  Distance
# 0  2015      5    7            3  1.683323
# ...

# %% [markdown]
# - Taking only the required columns

# %%
data.columns
# Out:
# Index(['ride_id', 'fare_amount', 'pickup_datetime', 'pickup_longitude',
#        'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude',
#        'passenger_count', 'Year', 'Month', 'Day', 'Day of Week', 'Distance'],
#       dtype='object')

# %%
df=data[['fare_amount', 'pickup_datetime', 'pickup_longitude',
       'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude',
       'passenger_count','Year','Month','Day','Day of Week']]
df
# Out:
#         fare_amount           pickup_datetime  pickup_longitude  \
# 0               7.5 2015-05-07 19:52:06+00:00        -73.999817
# 1               7.7 2009-07-17 20:04:56+00:00        -73.994355
# 2              12.9 2009-08-24 21:45:00+00:00        -74.005043
# 3               5.3 2009-06-26 08:22:21+00:00        -73.976124
# 4              16.0 2014-08-28 17:47:00+00:00        -73.925023
# ...             ...                       ...               ...
# 199995          3.0 2012-10-28 10:49:00+00:00        -73.987042
# 199996          7.5 2014-03-14 01:09:00+00:00        -73.984722
# 199997         30.9 2009-06-29 00:42:00+00:00        -73.986017
# 199998         14.5 2015-05-20 14:56:25+00:00        -73.997124
# 199999         14.1 2010-05-15 04:08:00+00:00        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 0             40.738354         -73.999512         40.723217                1
# ...

# %%
df['passenger_count'].unique()
# Out:
# array([  1,   3,   5,   2,   4,   6,   0, 208], dtype=int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199999 entries, 0 to 199999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   fare_amount        199999 non-null  float64
#  1   pickup_datetime    199999 non-null  datetime64[ns, UTC]
#  2   pickup_longitude   199999 non-null  float64
#  3   pickup_latitude    199999 non-null  float64
#  4   dropoff_longitude  199999 non-null  float64
#  5   dropoff_latitude   199999 non-null  float64
#  6   passenger_count    199999 non-null  int64
#  7   Year               199999 non-null  int64
#  8   Month              199999 non-null  int64
#  9   Day                199999 non-null  int64
#  10  Day of Week        199999 non-null  int64
# dtypes: datetime64[ns, UTC](1), float64(5), int64(5)
# memory usage: 18.3 MB

# %% [markdown]
# # EDA

# %% [markdown]
# - Histogram

# %%
sns.histplot(df['fare_amount'],binwidth=50,bins=20,color='pink')
plt.title('hist plot for fare column')
plt.show()

# %% [markdown]
# - in this plot maximum number of values in between 0-100

# %% [markdown]
# - Count plot

# %%
sns.histplot(df['fare_amount'], kde=True)
plt.xlabel('fare_amount')
plt.ylabel('Frequency')
plt.title('Distribution of fare_amount')
plt.show()

# %%
sns.countplot(x=df['passenger_count'])
plt.title("passenger_count v/s count")
plt.show()

# %% [markdown]
# - in this graph we can clearly see that monday maximum people are booking Uber in comparison to other day

# %%
# fig = px.scatter(df, x=df['passenger_count'], y=df['fare_amount'],animation_frame=df['passenger_count'], title='Scatter Plot for passenger_count v/s fare_amount ')
# fig.show()

# %%
sns.scatterplot(df, x=df['passenger_count'], y=df['fare_amount'],hue=df['passenger_count'],palette='viridis')
plt.title('Scatter Plot for passenger_count v/s fare_amount ')
plt.show()

# %%
grouped_df = df.groupby('Day of Week')['passenger_count'].sum()
grouped_df.plot(kind='bar')
plt.xlabel('Day of Week')
plt.ylabel('Passenger Count')
plt.show()

# %%
grouped_df = df.groupby('Year')['passenger_count'].sum()
grouped_df.plot(kind='bar')
plt.xlabel('Year')
plt.ylabel('Passenger Count')
plt.title('year v/s passenger count')
plt.show()

# %%
passenger_2014 = df[df['pickup_datetime'].dt.year == 2014]
group_quarters = passenger_2014.groupby(passenger_2014['pickup_datetime'].dt.quarter)['passenger_count'].sum()

# %%
group_quarters.plot(kind='bar')
plt.xlabel('Quarter')
plt.ylabel('Total Passenger Count')
plt.title('Total Passenger Count by Quarter in 2014')
plt.show()

# %% [markdown]
# # Box Plot

# %%
sns.boxenplot(df['fare_amount'])
plt.ylabel('fare_amount')
plt.title('fare_amount box plot')
plt.show()

# %% [markdown]
# # Voline plot

# %%
sns.violinplot(df['fare_amount'])
plt.ylabel('fare_amount')
plt.title('fare_amount violinplot')
plt.show()

# %% [markdown]
# # Heat Map

# %%
df.columns
# Out:
# Index(['fare_amount', 'pickup_datetime', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'passenger_count', 'Year',
#        'Month', 'Day', 'Day of Week'],
#       dtype='object')

# %%
dfplot=df[['fare_amount','passenger_count','Year','Month', 'Day', 'Day of Week']]
dfplot.sample(2)
# Out:
#         fare_amount  passenger_count  Year  Month  Day  Day of Week
# 182918         12.1                1  2011      8   16            1
# 192386         31.5                1  2015      4   13            0

# %%
sns.heatmap(dfplot.corr(),annot=True)
plt.show()

# %% [markdown]
# # Pair plot

# %%
sns.pairplot(dfplot)
plt.show()

# %% [markdown]
# # Ml approaches

# %% [markdown]
# - Taking required column for ml

# %%
data.columns
# Out:
# Index(['ride_id', 'fare_amount', 'pickup_datetime', 'pickup_longitude',
#        'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude',
#        'passenger_count', 'Year', 'Month', 'Day', 'Day of Week', 'Distance'],
#       dtype='object')

# %%
df=data[['fare_amount','passenger_count','Distance','Year', 'Month', 'Day', 'Day of Week']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199999 entries, 0 to 199999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   fare_amount      199999 non-null  float64
#  1   passenger_count  199999 non-null  int64
#  2   Distance         199999 non-null  float64
#  3   Year             199999 non-null  int64
#  4   Month            199999 non-null  int64
#  5   Day              199999 non-null  int64
#  6   Day of Week      199999 non-null  int64
# dtypes: float64(2), int64(5)
# memory usage: 16.2 MB

# %% [markdown]
# - Select Target columns

# %%
y=df['fare_amount']
x=df.drop(columns='fare_amount')

# %% [markdown]
# - Train and test the data

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=20)

# %%
xtrain.shape,xtest.shape,len(ytrain),len(ytest)
# Out:
# ((139999, 6), (60000, 6), 139999, 60000)

# %% [markdown]
# - LinearRegression

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
re=RandomForestRegressor(random_state=1)

# %%
re.fit(xtrain,ytrain)
# Out:
# RandomForestRegressor(random_state=1)

# %%
re_xtrainpredict = re.predict(xtrain)
re_xtestpredict = re.predict(xtest)

# %%
re_xtrainpredictsc = re.score(xtrain,ytrain)
re_xtrainpredictsc
# Out:
# 0.9475895638992513

# %%
re_xtestpredictsc = re.score(xtest,ytest)
re_xtestpredictsc
# Out:
# 0.7216510269721239
